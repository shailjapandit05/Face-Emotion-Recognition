# %%
import cv2

# %%
from deepface import DeepFace

# %%
faceCascade= cv2. CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
cap= cv2.VideoCapture(1)
if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")
    
while True:
    ret,frame= cap.read()
    result = DeepFace.analyze(frame, actions=['emotion'])
    gray =cv2. cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces=faceCascade.detectMultiScale(gray ,1.1,4)
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y), (x+w, y+h), ( 0,255,0),2)
    font= cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, result['dominant_emotion'],
           (50,50),
           font,3,
           (0,0,255),
           2,
           cv2.LINE_4)
    cv2.imshow('Demo video',frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14052/2736707099.py in <module>
#       7 while True:
#       8     ret,frame= cap.read()
# ----> 9     result = DeepFace.analyze(frame, actions=['emotion'])
#      10     gray =cv2. cvtColor(frame,cv2.COLOR_BGR2GRAY)
#      11     faces=faceCascade.detectMultiScale(gray ,1.1,4)
#
# ~\anaconda3\lib\site-packages\deepface\DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     391                         if action == 'emotion':
#     392                                 emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# ...

# %%
img = cv2.imread('C:/Users/spandit3/OneDrive - Cal State LA/Desktop/happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.13it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.001109004642785294,
#   'disgust': 1.489519662126182e-10,
#   'fear': 0.011070662003476173,
#   'happy': 0.7368576712906361,
#   'sad': 6.732186648150673e-05,
#   'surprise': 99.05930161476135,
#   'neutral': 0.19159544026479125},
#  'dominant_emotion': 'surprise',
#  'region': {'x': 904, 'y': 657, 'w': 1358, 'h': 1358},
#  'age': 24,
#  'gender': 'Woman',
#  'race': {'asian': 0.21133108530193567,
#   'indian': 2.719028852880001,
#   'black': 0.035637401742860675,
#   'white': 47.5123256444931,
#   'middle eastern': 30.79235553741455,
#   'latino hispanic': 18.729320168495178},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'surprise'

# %%
faceCascade= cv2. CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces= faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y), (x+w, y+h), ( 0,255,0),5)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font= cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions['dominant_emotion'],
           (0,50),
           font,10,
           (0,0,255),
           7,
           cv2.LINE_4)
# Out:
# array([[[206, 218, 228],
#         [206, 218, 228],
#         [206, 218, 228],
#         ...,
#         [ 46,  37,  23],
#         [ 46,  37,  23],
#         [ 46,  37,  23]],
#
#        [[207, 219, 229],
#         [207, 219, 229],
#         [207, 219, 229],
#         ...,
#         [ 46,  37,  23],
#         [ 47,  38,  24],
#         [ 47,  38,  24]],
#
#        [[207, 219, 229],
#         [207, 219, 229],
#         [207, 219, 229],
#         ...,
#         [ 47,  38,  24],
#         [ 47,  38,  24],
#         [ 47,  38,  24]],
#
#        ...,
#
#        [[199, 205, 210],
#         [199, 205, 210],
#         [198, 204, 209],
#         ...,
#         [110, 116, 129],
#         [110, 116, 129],
#         [110, 116, 129]],
#
#        [[200, 206, 211],
#         [200, 206, 211],
#         [200, 206, 211],
#         ...,
#         [108, 114, 127],
#         [108, 114, 127],
#         [108, 114, 127]],
#
#        [[202, 208, 213],
#         [201, 207, 212],
#         [201, 207, 212],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img1 = cv2.imread('C:/Users/spandit3/OneDrive - Cal State LA/Desktop/sadwoman.jpg')

# %%
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img1)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.15it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 23.007608712626542,
#   'disgust': 0.5042066001691342,
#   'fear': 5.489629788950657,
#   'happy': 0.28160224766013,
#   'sad': 43.497442423992446,
#   'surprise': 0.00754234296308821,
#   'neutral': 27.211973334786098},
#  'dominant_emotion': 'sad',
#  'region': {'x': 2163, 'y': 432, 'w': 2238, 'h': 2238},
#  'age': 24,
#  'gender': 'Woman',
#  'race': {'asian': 0.10613932871647731,
#   'indian': 0.21817562829099557,
#   'black': 0.004373828257224507,
#   'white': 69.61989764930038,
#   'middle eastern': 17.624450609153435,
#   'latino hispanic': 12.426960476999225},
#  'dominant_race': 'white'}
